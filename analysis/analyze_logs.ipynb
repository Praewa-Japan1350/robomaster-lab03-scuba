# %% [markdown]
# # Analyze RoboMaster Sensor Logs
#
# Notebook สำหรับวิเคราะห์ผลการวิ่งของหุ่นยนต์ RoboMaster EP
# - โหลดไฟล์ CSV จาก `data/raw/`
# - พลอตกราฟ IMU (Accelerometer / Gyroscope)
# - บันทึกรูปกราฟไปที่ `analysis/plots/`

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# ตั้งค่า matplotlib ให้แสดงผลสวยงาม
try:
    plt.style.use('seaborn-v0_8-whitegrid')
except Exception:
    try:
        plt.style.use('seaborn-whitegrid')
    except Exception:
        pass

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %%
# โหลดข้อมูลจากไฟล์ CSV
# เปลี่ยน path ให้ตรงกับไฟล์ที่ต้องการวิเคราะห์
csv_path = os.path.join('..', 'data', 'raw', 'run1', 'lab1_sensor_data.csv')

if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    print(f'Loaded {len(df)} rows from {csv_path}')
    df.head()
# Out:
# Loaded 184 rows from ..\data\raw\run1\lab1_sensor_data.csv

# %%
# พลอตกราฟ Accelerometer
if 'df' in dir():
    fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    # Accelerometer
    axes[0].plot(df['timestamp'], df['acc_x'], label='acc_x')
    axes[0].plot(df['timestamp'], df['acc_y'], label='acc_y')
    axes[0].plot(df['timestamp'], df['acc_z'], label='acc_z')
    axes[0].set_ylabel('Acceleration (m/s²)')
    axes[0].set_title('IMU Accelerometer')
    axes[0].legend()

    # Gyroscope
    axes[1].plot(df['timestamp'], df['gyro_x'], label='gyro_x')
    axes[1].plot(df['timestamp'], df['gyro_y'], label='gyro_y')
    axes[1].plot(df['timestamp'], df['gyro_z'], label='gyro_z')
    axes[1].set_ylabel('Angular Velocity (°/s)')
    axes[1].set_xlabel('Time')
    axes[1].set_title('IMU Gyroscope')
    axes[1].legend()

    plt.tight_layout()

    # บันทึกรูปกราฟ
    output_path = os.path.join('..', 'analysis', 'plots', 'plot_imu.png')
    plt.savefig(output_path, dpi=150, bbox_inches='tight')
    print(f'Plot saved to {output_path}')
    plt.show()
# Out:
# Plot saved to ..\analysis\plots\plot_imu.png

# %% [markdown]
# ### 📊 ผลการพลอตกราฟ IMU (Accelerometer & Gyroscope)
#
# ![IMU Plot](plots/plot_imu.png)
